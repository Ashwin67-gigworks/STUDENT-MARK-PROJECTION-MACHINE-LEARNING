# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import GridSearchCV
from lightgbm import LGBMRegressor
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import joblib

# %%
df = pd.read_csv('/content/archive (1).zip')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
scores = df.columns[df.columns.str.contains('score')].tolist()
scores
# Out:
# ['math score', 'reading score', 'writing score']

# %% [markdown]
# EDA:
#
# histograms:

# %%
for score in scores:
    sns.histplot(df[score], element='bars', kde=True)
    plt.text(x=20, y=90, s=f"Skew: {round(df[score].skew(),2)}\nKurtosis: {round(df[score].kurt(),2)}")
    plt.show()

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# pariplot:

# %%
sns.pairplot(data=df)

# %% [markdown]
# scores vs lunch type:

# %%
for score in scores:
    sns.boxplot(y=df[score], x=df['lunch'])
    plt.show()

# %% [markdown]
# scores vs race/ ethnicity group:

# %%
for score in scores:
    sns.boxplot(y=df[score], x=df['race/ethnicity'], order=sorted(df['race/ethnicity'].unique()))
    plt.show()

# %%
for score in scores:
    sns.boxplot(y=df[score], x=df['gender'])
    plt.show()

# %% [markdown]
# scores vs whether completed the test prep course:

# %%
for score in scores:
    sns.boxplot(y=df[score], x=df['test preparation course'])
    plt.show()

# %% [markdown]
# scores vs parental education level:

# %%
for score in scores:
    plt.figure(figsize=(10,5))
    sns.boxplot(y=df[score], x=df['parental level of education'])
    plt.xticks(rotation=15)
    plt.show()

# %%
X, y = df.drop('writing score', axis=1), df['writing score']

# %%
cat_cols = X.dtypes[X.dtypes == 'O'].index.tolist()
cat_cols
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course']

# %%
ct = ColumnTransformer([
#     ('num', StandardScaler(), ['reading score', 'math score']),
    ('ohe', OneHotEncoder(sparse=False, handle_unknown='ignore'), cat_cols)
], remainder='passthrough')

# %%
ct.fit_transform(X).shape
# Out:
# (1000, 19)

# %%
pipe = Pipeline([
    ('trf', ct),
    ('model', LGBMRegressor(random_state=0))
])

# %%
params = {
    'model__n_estimators':[100,130,150,170,190],
    'model__boosting_type': ['dart', 'gbdt', 'goss']
}

# %%
gs = GridSearchCV(pipe, param_grid=params, scoring='neg_root_mean_squared_error', n_jobs=-1)

# %%
gs.fit(X, y)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('trf',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ohe',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          ['gender',
#                                                                           'race/ethnicity',
#                                                                           'parental '
#                                                                           'level '
#                                                                           'of '
#                                                                           'education',
#                                                                           'lunch',
#                                                                           'test '
#                                                                           'preparation '
#                                                                           'course'])])),
#                                        ('model',
#                                         LGBMRegressor(random_state=0))]),
#              n_jobs=-1,
#              param_grid={'model__boosting_type': ['dart', 'gbdt', 'goss'],
#                          'model__n_estimators': [100, 130, 150, 170, 190]},
#              scoring='neg_root_mean_squared_error')

# %%
pd.DataFrame(gs.cv_results_).sort_values(by='rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5        0.080462      0.009295         0.008074        0.000192
# 6        0.097232      0.004538         0.008948        0.000453
# 7        0.107189      0.003380         0.010279        0.001920
# 8        0.124185      0.005288         0.010690        0.001982
# 9        0.132959      0.003936         0.010685        0.000701
# 11       0.056311      0.004278         0.008145        0.000564
# 14       0.065846      0.011335         0.007858        0.001140
# 13       0.065103      0.004559         0.008052        0.000301
# 4        0.299824      0.007344         0.009304        0.000641
# 10       0.048144      0.002866         0.008454        0.002203
# 2        0.218273      0.010058         0.009700        0.001357
# 3        0.260154      0.009135         0.010890        0.002088
# 12       0.063086      0.007856         0.007984        0.000277
# 1        0.178287      0.007671         0.008442        0.000128
# 0        0.126756      0.007310         0.008241        0.000166
#
#    param_model__boosting_type param_model__n_estimators  \
# 5                        gbdt                       100
# 6                        gbdt                       130
# 7                        gbdt                       150
# 8                        gbdt                       170
# 9                        gbdt                       190
# 11                       goss                       130
# 14                       goss                       190
# 13                       goss                       170
# 4                        dart                       190
# 10                       goss                       100
# 2                        dart                       150
# 3                        dart                       170
# 12                       goss                       150
# 1                        dart                       130
# 0                        dart                       100
#
#                                                params  split0_test_score  \
# 5   {'model__boosting_type': 'gbdt', 'model__n_est...          -4.394029
# 6   {'model__boosting_type': 'gbdt', 'model__n_est...          -4.425160
# 7   {'model__boosting_type': 'gbdt', 'model__n_est...          -4.446083
# 8   {'model__boosting_type': 'gbdt', 'model__n_est...          -4.469208
# 9   {'model__boosting_type': 'gbdt', 'model__n_est...          -4.520730
# 11  {'model__boosting_type': 'goss', 'model__n_est...          -4.656370
# 14  {'model__boosting_type': 'goss', 'model__n_est...          -4.672582
# 13  {'model__boosting_type': 'goss', 'model__n_est...          -4.854100
# 4   {'model__boosting_type': 'dart', 'model__n_est...          -5.197361
# 10  {'model__boosting_type': 'goss', 'model__n_est...          -4.657253
# 2   {'model__boosting_type': 'dart', 'model__n_est...          -6.052651
# 3   {'model__boosting_type': 'dart', 'model__n_est...          -6.862467
# 12  {'model__boosting_type': 'goss', 'model__n_est...          -5.965764
# 1   {'model__boosting_type': 'dart', 'model__n_est...          -7.206752
# 0   {'model__boosting_type': 'dart', 'model__n_est...          -9.481299
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 5           -3.919853          -3.790584          -3.823524
# 6           -3.945710          -3.813887          -3.904709
# 7           -3.938389          -3.830534          -3.920707
# 8           -3.949160          -3.860081          -3.933425
# 9           -3.977621          -3.891544          -3.949715
# 11          -5.450082          -4.312217          -3.879143
# 14          -5.326299          -4.311915          -4.079921
# 13          -5.340081          -4.433902          -3.949151
# 4           -5.100846          -5.104413          -5.218522
# 10          -5.573131          -4.504096          -3.926161
# 2           -6.042155          -6.087492          -6.189927
# 3           -6.885027          -6.946315          -7.084104
# 12         -11.206092          -4.528518          -4.795796
# 1           -7.233682          -7.313913          -7.452258
# 0           -9.543847          -9.679220          -9.827518
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 5           -4.038057        -3.993209        0.218128                1
# 6           -4.083423        -4.034578        0.213733                2
# 7           -4.117453        -4.050633        0.218526                3
# 8           -4.150942        -4.072563        0.220548                4
# 9           -4.160099        -4.099942        0.228754                5
# 11          -5.276758        -4.714914        0.586557                6
# 14          -5.460661        -4.770275        0.544430                7
# 13          -5.808151        -4.877077        0.654102                8
# 4           -5.478813        -5.219991        0.137882                9
# 10          -7.660749        -5.264278        1.309609               10
# 2           -6.453704        -6.165186        0.153422               11
# 3           -7.278795        -7.011342        0.154385               12
# 12          -9.382121        -7.175658        2.655101               13
# 1           -7.678857        -7.377092        0.173370               14
# 0          -10.034155        -9.713208        0.199847               15

# %%
gs.best_params_
# Out:
# {'model__boosting_type': 'gbdt', 'model__n_estimators': 100}

# %%
gs.best_score_
# Out:
# -3.9932092796716128

# %%
gs.best_estimator_
# Out:
# Pipeline(steps=[('trf',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   ['gender', 'race/ethnicity',
#                                                    'parental level of '
#                                                    'education',
#                                                    'lunch',
#                                                    'test preparation '
#                                                    'course'])])),
#                 ('model', LGBMRegressor(random_state=0))])

# %%
joblib.dump(gs.best_estimator_, 'model.joblib')
# Out:
# ['model.joblib']

# %% [markdown]
# importing the model:

# %%
mdl = joblib.load('model.joblib')

# %% [markdown]
# Making predictions on a new data point NOT seen by the model

# %%
q = pd.DataFrame([['female', 'group A', 'high school', 'standard', 'completed', 50,87]],
             columns=X.columns)
q
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group A                 high school  standard
#
#   test preparation course  math score  reading score
# 0               completed          50             87

# %%
mdl.predict(q)
# Out:
# array([81.87659159])
